# %% [markdown]
# <a href="https://colab.research.google.com/github/mirpouya/Northwind-DWH/blob/main/Analytics_1_(CSV)_Northwind_Traders_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
categories = pd.read_csv('categories.csv')
categories.head()
# Out:
#    categoryID      categoryName  \
# 0           1         Beverages
# 1           2        Condiments
# 2           3       Confections
# 3           4    Dairy Products
# 4           5  Grains & Cereals
#
#                                          description
# 0        Soft drinks, coffees, teas, beers, and ales
# 1  Sweet and savory sauces, relishes, spreads, an...
# 2                Desserts, candies, and sweet breads
# 3                                            Cheeses
# 4                Breads, crackers, pasta, and cereal

# %%
categories.isnull().sum()
# Out:
# categoryID      0
# categoryName    0
# description     0
# dtype: int64

# %%
customers = pd.read_csv('customers.csv', encoding='latin1')
customers.head()
# Out:
#   customerID                         companyName         contactName  \
# 0      ALFKI                 Alfreds Futterkiste        Maria Anders
# 1      ANATR  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2      ANTON             Antonio Moreno Taquería      Antonio Moreno
# 3      AROUT                     Around the Horn        Thomas Hardy
# 4      BERGS                  Berglunds snabbköp  Christina Berglund
#
#            contactTitle         city  country
# 0  Sales Representative       Berlin  Germany
# 1                 Owner  Mexico City   Mexico
# 2                 Owner  Mexico City   Mexico
# 3  Sales Representative       London       UK
# 4   Order Administrator        Luleå   Sweden

# %%
customers.isnull().sum()
# Out:
# customerID      0
# companyName     0
# contactName     0
# contactTitle    0
# city            0
# country         0
# dtype: int64

# %%
employees = pd.read_csv('employees.csv')
employees.head()
# Out:
#    employeeID      employeeName                 title      city country  \
# 0           1     Nancy Davolio  Sales Representative  New York     USA
# 1           2     Andrew Fuller  Vice President Sales  New York     USA
# 2           3   Janet Leverling  Sales Representative  New York     USA
# 3           4  Margaret Peacock  Sales Representative  New York     USA
# 4           5   Steven Buchanan         Sales Manager    London      UK
#
#    reportsTo
# 0        8.0
# 1        NaN
# 2        8.0
# 3        8.0
# 4        2.0

# %%
employees.isnull().sum()
# Out:
# employeeID      0
# employeeName    0
# title           0
# city            0
# country         0
# reportsTo       1
# dtype: int64

# %%
# Convert 'reportsTo' column to numeric type if needed
employees['reportsTo'] = pd.to_numeric(employees['reportsTo'], errors='coerce')

# Fill missing values with -1
employees['reportsTo'].fillna(-1, inplace=True)

# Verify the changes
print(employees['reportsTo'].isnull().sum())
# Out:
# 0

# %%
order_details = pd.read_csv('order_details.csv')
order_details.head()
# Out:
#    orderID  productID  unitPrice  quantity  discount
# 0    10248         11       14.0        12       0.0
# 1    10248         42        9.8        10       0.0
# 2    10248         72       34.8         5       0.0
# 3    10249         14       18.6         9       0.0
# 4    10249         51       42.4        40       0.0

# %%
order_details.isnull().sum()
# Out:
# orderID      0
# productID    0
# unitPrice    0
# quantity     0
# discount     0
# dtype: int64

# %%
orders = pd.read_csv('orders.csv')
orders.head()
# Out:
#    orderID customerID  employeeID   orderDate requiredDate shippedDate  \
# 0    10248      VINET           5  2013-07-04   2013-08-01  2013-07-16
# 1    10249      TOMSP           6  2013-07-05   2013-08-16  2013-07-10
# 2    10250      HANAR           4  2013-07-08   2013-08-05  2013-07-12
# 3    10251      VICTE           3  2013-07-08   2013-08-05  2013-07-15
# 4    10252      SUPRD           4  2013-07-09   2013-08-06  2013-07-11
#
#    shipperID  freight
# 0          3    32.38
# 1          1    11.61
# 2          2    65.83
# 3          1    41.34
# 4          2    51.30

# %%
orders.isnull().sum()
# Out:
# orderID          0
# customerID       0
# employeeID       0
# orderDate        0
# requiredDate     0
# shippedDate     21
# shipperID        0
# freight          0
# dtype: int64

# %%
# Fill missing values in 'shippedDate' column with a default date or a specific value
orders['shippedDate'].fillna('Not Shipped', inplace=True)

# %%
orders.isnull().sum()
# Out:
# orderID         0
# customerID      0
# employeeID      0
# orderDate       0
# requiredDate    0
# shippedDate     0
# shipperID       0
# freight         0
# dtype: int64

# %%
products = pd.read_csv('products.csv', encoding='latin1')
products.head()
# Out:
#    productID                   productName      quantityPerUnit  unitPrice  \
# 0          1                          Chai   10 boxes x 20 bags      18.00
# 1          2                         Chang   24 - 12 oz bottles      19.00
# 2          3                 Aniseed Syrup  12 - 550 ml bottles      10.00
# 3          4  Chef Anton's Cajun Seasoning       48 - 6 oz jars      22.00
# 4          5        Chef Anton's Gumbo Mix             36 boxes      21.35
#
#    discontinued  categoryID
# 0             0           1
# 1             0           1
# 2             0           2
# 3             0           2
# 4             1           2

# %%
products.isnull().sum()
# Out:
# productID          0
# productName        0
# quantityPerUnit    0
# unitPrice          0
# discontinued       0
# categoryID         0
# dtype: int64

# %%
shippers = pd.read_csv('shippers.csv')
shippers.head()
# Out:
#    shipperID       companyName
# 0          1    Speedy Express
# 1          2    United Package
# 2          3  Federal Shipping

# %%
 shippers.isnull().sum()
# Out:
# shipperID      0
# companyName    0
# dtype: int64

# %%
# Print each DataFrame
print("Categories DataFrame:")
print(categories.head())

print("\nCustomers DataFrame:")
print(customers.head())

print("\nEmployees DataFrame:")
print(employees.head())

print("\nOrder Details DataFrame:")
print(order_details.head())

print("\nOrders DataFrame:")
print(orders.head())

print("\nProducts DataFrame:")
print(products.head())

print("\nShippers DataFrame:")
print(shippers.head())
# Out:
# Categories DataFrame:
#    categoryID      categoryName  \
# 0           1         Beverages
# 1           2        Condiments
# 2           3       Confections
# 3           4    Dairy Products
# 4           5  Grains & Cereals
#
#                                          description
# 0        Soft drinks, coffees, teas, beers, and ales
# 1  Sweet and savory sauces, relishes, spreads, an...
# 2                Desserts, candies, and sweet breads
# 3                                            Cheeses
# 4                Breads, crackers, pasta, and cereal
#
# Customers DataFrame:
#   customerID                         companyName         contactName  \
# 0      ALFKI                 Alfreds Futterkiste        Maria Anders
# 1      ANATR  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2      ANTON             Antonio Moreno Taquería      Antonio Moreno
# 3      AROUT                     Around the Horn        Thomas Hardy
# 4      BERGS                  Berglunds snabbköp  Christina Berglund
#
#            contactTitle         city  country
# 0  Sales Representative       Berlin  Germany
# 1                 Owner  Mexico City   Mexico
# 2                 Owner  Mexico City   Mexico
# 3  Sales Representative       London       UK
# 4   Order Administrator        Luleå   Sweden
#
# Employees DataFrame:
#    employeeID      employeeName                 title      city country  \
# 0           1     Nancy Davolio  Sales Representative  New York     USA
# 1           2     Andrew Fuller  Vice President Sales  New York     USA
# 2           3   Janet Leverling  Sales Representative  New York     USA
# 3           4  Margaret Peacock  Sales Representative  New York     USA
# 4           5   Steven Buchanan         Sales Manager    London      UK
#
#    reportsTo
# 0        8.0
# 1       -1.0
# 2        8.0
# 3        8.0
# 4        2.0
#
# Order Details DataFrame:
#    orderID  productID  unitPrice  quantity  discount
# 0    10248         11       14.0        12       0.0
# 1    10248         42        9.8        10       0.0
# 2    10248         72       34.8         5       0.0
# 3    10249         14       18.6         9       0.0
# 4    10249         51       42.4        40       0.0
#
# Orders DataFrame:
#    orderID customerID  employeeID   orderDate requiredDate shippedDate  \
# 0    10248      VINET           5  2013-07-04   2013-08-01  2013-07-16
# 1    10249      TOMSP           6  2013-07-05   2013-08-16  2013-07-10
# 2    10250      HANAR           4  2013-07-08   2013-08-05  2013-07-12
# 3    10251      VICTE           3  2013-07-08   2013-08-05  2013-07-15
# 4    10252      SUPRD           4  2013-07-09   2013-08-06  2013-07-11
#
#    shipperID  freight
# 0          3    32.38
# 1          1    11.61
# 2          2    65.83
# 3          1    41.34
# 4          2    51.30
#
# Products DataFrame:
#    productID                   productName      quantityPerUnit  unitPrice  \
# 0          1                          Chai   10 boxes x 20 bags      18.00
# 1          2                         Chang   24 - 12 oz bottles      19.00
# 2          3                 Aniseed Syrup  12 - 550 ml bottles      10.00
# 3          4  Chef Anton's Cajun Seasoning       48 - 6 oz jars      22.00
# 4          5        Chef Anton's Gumbo Mix             36 boxes      21.35
#
#    discontinued  categoryID
# 0             0           1
# 1             0           1
# 2             0           2
# 3             0           2
# 4             1           2
#
# Shippers DataFrame:
#    shipperID       companyName
# 0          1    Speedy Express
# 1          2    United Package
# 2          3  Federal Shipping

# %%
import pandas as pd

# Merge Categories and Products DataFrames on 'categoryID'
merged_data = pd.merge(categories, products, on='categoryID')

# Merge merged_data and Order Details DataFrames on 'productID'
merged_data = pd.merge(merged_data, order_details, on='productID')

# Merge merged_data and Orders DataFrames on 'orderID'
merged_data = pd.merge(merged_data, orders, on='orderID')

# Merge merged_data and Customers DataFrames on 'customerID'
merged_data = pd.merge(merged_data, customers, on='customerID')

# Merge merged_data and Employees DataFrames on 'employeeID'
merged_data = pd.merge(merged_data, employees, on='employeeID')

# Merge merged_data and Shippers DataFrames on 'shipperID'
merged_data = pd.merge(merged_data, shippers, on='shipperID')

# Print the merged dataset
print(merged_data)
# Out:
#       categoryID    categoryName                                  description  \
# 0              1       Beverages  Soft drinks, coffees, teas, beers, and ales
# 1              6  Meat & Poultry                               Prepared meats
# 2              8         Seafood                             Seaweed and fish
# 3              1       Beverages  Soft drinks, coffees, teas, beers, and ales
# 4              4  Dairy Products                                      Cheeses
# ...          ...             ...                                          ...
# 2150           8         Seafood                             Seaweed and fish
# 2151           1       Beverages  Soft drinks, coffees, teas, beers, and ales
# 2152           7         Produce                    Dried fruit and bean curd
# 2153           1       Beverages  Soft drinks, coffees, teas, beers, and ales
# 2154           3     Confections          Desserts, candies, and sweet breads
#
#       productID            productName      quantityPerUnit  unitPrice_x  \
# 0             1                   Chai   10 boxes x 20 bags        18.00
# 1            53          Perth Pasties            48 pieces        32.80
# 2            40       Boston Crab Meat       24 - 4 oz tins        18.40
# 3            39       Chartreuse verte    750 cc per bottle        18.00
# 4            60      Camembert Pierrot    15 - 300 g rounds        34.00
# ...         ...                    ...                  ...          ...
# 2150         46              Spegesild    4 - 450 g glasses        12.00
# 2151         75   Rhönbräu Klosterbier   24 - 0.5 l bottles         7.75
# 2152         51  Manjimup Dried Apples     50 - 300 g pkgs.        53.00
# 2153         70          Outback Lager  24 - 355 ml bottles        15.00
# 2154         62         Tarte au sucre              48 pies        49.30
#
#       discontinued  orderID  unitPrice_y  ...        contactName  \
# 0                0    10285        14.40  ...        Horst Kloss
# 1                1    10285        26.20  ...        Horst Kloss
# 2                0    10285        14.70  ...        Horst Kloss
# 3                0    10361        14.40  ...        Horst Kloss
# 4                0    10361        27.20  ...        Horst Kloss
# ...            ...      ...          ...  ...                ...
# 2150             0    11019        12.00  ...   Sergio Gutiérrez
# 2151             0    10907         7.75  ...  Dominique Perrier
# 2152             0    10965        53.00  ...      Rene Phillips
# 2153             0    10822        15.00  ...     Helvetius Nagy
# 2154             0    10822        49.30  ...     Helvetius Nagy
#
#               contactTitle        city_x  country_x    employeeName  \
# 0       Accounting Manager     Cunewalde    Germany   Nancy Davolio
# 1       Accounting Manager     Cunewalde    Germany   Nancy Davolio
# 2       Accounting Manager     Cunewalde    Germany   Nancy Davolio
# 3       Accounting Manager     Cunewalde    Germany   Nancy Davolio
# 4       Accounting Manager     Cunewalde    Germany   Nancy Davolio
# ...                    ...           ...        ...             ...
# 2150  Sales Representative  Buenos Aires  Argentina  Michael Suyama
# 2151     Marketing Manager         Paris     France  Michael Suyama
# 2152  Sales Representative     Anchorage        USA  Michael Suyama
# 2153       Sales Associate      Kirkland        USA  Michael Suyama
# 2154       Sales Associate      Kirkland        USA  Michael Suyama
#
#                      title    city_y  country_y  reportsTo     companyName_y
# 0     Sales Representative  New York        USA        8.0    United Package
# 1     Sales Representative  New York        USA        8.0    United Package
# 2     Sales Representative  New York        USA        8.0    United Package
# 3     Sales Representative  New York        USA        8.0    United Package
# 4     Sales Representative  New York        USA        8.0    United Package
# ...                    ...       ...        ...        ...               ...
# 2150  Sales Representative    London         UK        5.0  Federal Shipping
# 2151  Sales Representative    London         UK        5.0  Federal Shipping
# 2152  Sales Representative    London         UK        5.0  Federal Shipping
# 2153  Sales Representative    London         UK        5.0  Federal Shipping
# 2154  Sales Representative    London         UK        5.0  Federal Shipping
#
# [2155 rows x 30 columns]

# %%
merged_data.head()
# Out:
#    categoryID    categoryName                                  description  \
# 0           1       Beverages  Soft drinks, coffees, teas, beers, and ales
# 1           6  Meat & Poultry                               Prepared meats
# 2           8         Seafood                             Seaweed and fish
# 3           1       Beverages  Soft drinks, coffees, teas, beers, and ales
# 4           4  Dairy Products                                      Cheeses
#
#    productID        productName     quantityPerUnit  unitPrice_x  \
# 0          1               Chai  10 boxes x 20 bags         18.0
# 1         53      Perth Pasties           48 pieces         32.8
# 2         40   Boston Crab Meat      24 - 4 oz tins         18.4
# 3         39   Chartreuse verte   750 cc per bottle         18.0
# 4         60  Camembert Pierrot   15 - 300 g rounds         34.0
#
#    discontinued  orderID  unitPrice_y  ...  contactName        contactTitle  \
# 0             0    10285         14.4  ...  Horst Kloss  Accounting Manager
# 1             1    10285         26.2  ...  Horst Kloss  Accounting Manager
# 2             0    10285         14.7  ...  Horst Kloss  Accounting Manager
# 3             0    10361         14.4  ...  Horst Kloss  Accounting Manager
# 4             0    10361         27.2  ...  Horst Kloss  Accounting Manager
#
#       city_x  country_x   employeeName                 title    city_y  \
# 0  Cunewalde    Germany  Nancy Davolio  Sales Representative  New York
# 1  Cunewalde    Germany  Nancy Davolio  Sales Representative  New York
# 2  Cunewalde    Germany  Nancy Davolio  Sales Representative  New York
# 3  Cunewalde    Germany  Nancy Davolio  Sales Representative  New York
# 4  Cunewalde    Germany  Nancy Davolio  Sales Representative  New York
#
#    country_y  reportsTo   companyName_y
# 0        USA        8.0  United Package
# 1        USA        8.0  United Package
# 2        USA        8.0  United Package
# 3        USA        8.0  United Package
# 4        USA        8.0  United Package
#
# [5 rows x 30 columns]

# %%
from powerbiclient import QuickVisualize, get_dataset_config, Report
from powerbiclient.authentication import DeviceCodeLoginAuthentication

# %%
from powerbiclient import QuickVisualize, get_dataset_config
from powerbiclient.authentication import DeviceCodeLoginAuthentication

# Define the authentication method (Device Code Login)
device_auth = DeviceCodeLoginAuthentication()

# Specify the dataset configuration for your data
dataset_config = get_dataset_config(merged_data)

# Create a Power BI report from the data
pbi_visualize = QuickVisualize(dataset_config, auth=device_auth)

pbi_visualize
# Out:
# Performing device flow authentication. Please follow the instructions below.
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code D7WTQE2WU to authenticate.
#
# Device flow authentication successfully completed.
# You are now logged in .
#
# The result should be passed only to trusted code in your notebook.
# QuickVisualize()

# %% [markdown]
# ##EDA

# %%
# Count the number of products in each category
category_counts = merged_data['categoryName'].value_counts()

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(category_counts.index, category_counts.values)

# Add labels and title
plt.xlabel('Category')
plt.ylabel('Number of Products')
plt.title('Product Distribution by Category')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Display the chart
plt.tight_layout()
plt.show()

# %%
# Calculate the percentage of products in each category
category_percentages = (merged_data['categoryName'].value_counts() / len(merged_data)) * 100

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(category_percentages, labels=category_percentages.index, autopct='%1.1f%%', startangle=90)

# Add title
plt.title('Product Distribution by Category')

# Display the chart
plt.axis('equal')
plt.show()

# %%
# Create a histogram of product prices
plt.figure(figsize=(10, 6))
plt.hist(merged_data['unitPrice_x'], bins=10, edgecolor='black')

# Add labels and title
plt.xlabel('Unit Price')
plt.ylabel('Frequency')
plt.title('Distribution of Product Prices')

# Display the chart
plt.show()

# %%
# Create a scatter plot of product quantity vs. price
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
plt.scatter(merged_data['quantityPerUnit'], merged_data['unitPrice_x'], alpha=0.5)

# Add labels and title
plt.xlabel('Quantity Per Unit')
plt.ylabel('Unit Price')
plt.title('Product Quantity vs. Price')

# Display the chart
plt.show()

# %%
# Calculate the average unit price by category
average_price_by_category = merged_data.groupby('categoryName')['unitPrice_x'].mean()

# Create a bar chart
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
average_price_by_category.plot(kind='bar', color='steelblue')

# Add labels and title
plt.xlabel('Category')
plt.ylabel('Average Unit Price')
plt.title('Average Unit Price by Category')

# Display the chart
plt.show()

# %%
# Create a box plot of product prices by category
plt.figure(figsize=(10, 6))
sns.boxplot(x='categoryName', y='unitPrice_x', data=merged_data)

# Add labels and title
plt.xlabel('Category')
plt.ylabel('Unit Price')
plt.title('Distribution of Product Prices by Category')

# Rotate x-axis labels if needed
plt.xticks(rotation=45)

# Display the chart
plt.show()

# %%
# Create a scatter plot of unit price vs. quantity
plt.figure(figsize=(10, 6))
plt.scatter(merged_data['unitPrice_x'], merged_data['quantity'], color='steelblue')

# Add labels and title
plt.xlabel('Unit Price')
plt.ylabel('Quantity')
plt.title('Unit Price vs. Quantity')

# Display the chart
plt.show()

# %%
# Select the numerical columns for correlation analysis
numeric_columns = ['unitPrice_x', 'quantity', 'discount', 'freight']

# Calculate the correlation matrix
correlation_matrix = merged_data[numeric_columns].corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')

# Add title
plt.title('Correlation Matrix')

# Display the chart
plt.show()

# %%
# Convert the orderDate column to datetime type
merged_data['orderDate'] = pd.to_datetime(merged_data['orderDate'])

# Group the data by orderDate and calculate the total order amount
daily_order_amount = merged_data.groupby('orderDate')['unitPrice_y'].sum()

# Create a line plot of daily order amounts
plt.figure(figsize=(10, 6))
plt.plot(daily_order_amount.index, daily_order_amount.values, color='steelblue')
plt.xlabel('Date')
plt.ylabel('Total Order Amount')
plt.title('Daily Total Order Amount')
plt.show()

# %%
# Perform customer segmentation
# Example: Group customers based on total purchase value
customer_segments = merged_data.groupby('customerID')['unitPrice_x'].sum()

# Create customer profiles
customer_profiles = pd.DataFrame()
customer_profiles['customerID'] = customer_segments.index
customer_profiles['totalPurchaseValue'] = customer_segments.values

# Print the customer profiles
print(customer_profiles)
# Out:
#    customerID  totalPurchaseValue
# 0       ALFKI              320.85
# 1       ANATR              225.25
# 2       ANTON              373.43
# 3       AROUT              597.70
# 4       BERGS             1507.48
# ..        ...                 ...
# 84      WARTH              945.79
# 85      WELLI              516.50
# 86      WHITC             1314.93
# 87      WILMK              427.70
# 88      WOLZA              335.25
#
# [89 rows x 2 columns]

# %%
merged_data.columns
# Out:
# Index(['categoryID', 'categoryName', 'description', 'productID', 'productName',
#        'quantityPerUnit', 'unitPrice_x', 'discontinued', 'orderID',
#        'unitPrice_y', 'quantity', 'discount', 'customerID', 'employeeID',
#        'orderDate', 'requiredDate', 'shippedDate', 'shipperID', 'freight',
#        'companyName_x', 'contactName', 'contactTitle', 'city_x', 'country_x',
#        'employeeName', 'title', 'city_y', 'country_y', 'reportsTo',
#        'companyName_y'],
#       dtype='object')

# %%
from sklearn.cluster import KMeans

# Perform customer segmentation
customer_segments = merged_data.groupby('customerID')['unitPrice_x'].sum()

# Create customer profiles
customer_profiles = pd.DataFrame()
customer_profiles['customerID'] = customer_segments.index
customer_profiles['totalPurchaseValue'] = customer_segments.values

# Perform clustering
X = customer_profiles[['totalPurchaseValue']]
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X)
customer_profiles['segment'] = kmeans.labels_

# Visualize customer segments
plt.figure(figsize=(30, 10))
colors = ['red', 'blue', 'green']
for segment in customer_profiles['segment'].unique():
    segment_data = customer_profiles[customer_profiles['segment'] == segment]
    plt.scatter(segment_data['customerID'], segment_data['totalPurchaseValue'], color=colors[segment])
plt.xlabel('Customer ID')
plt.ylabel('Total Purchase Value')
plt.title('Customer Segmentation based on Total Purchase Value')
plt.legend(customer_profiles['segment'].unique())
plt.show()

# Print the customer profiles with segments
print(customer_profiles)
# Out:
# C:\Users\hDibie\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\hDibie\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
#    customerID  totalPurchaseValue  segment
# 0       ALFKI              320.85        0
# 1       ANATR              225.25        0
# 2       ANTON              373.43        0
# 3       AROUT              597.70        0
# 4       BERGS             1507.48        1
# ..        ...                 ...      ...
# 84      WARTH              945.79        1
# 85      WELLI              516.50        0
# 86      WHITC             1314.93        1
# 87      WILMK              427.70        0
# 88      WOLZA              335.25        0
#
# [89 rows x 3 columns]

# %% [markdown]
# ##Market Analysis

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# Perform one-hot encoding on the merged_data for market basket analysis
basket = merged_data.groupby(['orderID', 'productName'])['quantity'].sum().unstack().reset_index().fillna(0).set_index('orderID')

# Convert the quantity values to binary values (0 or 1)
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

basket_sets = basket.applymap(encode_units)

# Perform market basket analysis using the Apriori algorithm
frequent_itemsets = apriori(basket_sets, min_support=0.05, use_colnames=True)

# Generate association rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# Print the frequent itemsets
print("Frequent Itemsets:")
print(frequent_itemsets)

# Print the association rules
print("\nAssociation Rules:")
print(rules)
# Out:
# Frequent Itemsets:
#      support                           itemsets
# 0   0.061446                (Camembert Pierrot)
# 1   0.053012                            (Chang)
# 2   0.050602                      (Flotemysost)
# 3   0.060241           (Gnocchi di nonna Alice)
# 4   0.061446                (Gorgonzola Telino)
# 5   0.061446               (Guarana Fantastica)
# 6   0.056627  (Jack's New England Clam Chowder)
# 7   0.051807                          (Pavlova)
# 8   0.065060             (Raclette Courdavault)
# 9   0.055422             (Rhönbräu Klosterbier)
# 10  0.057831                   (Tarte au sucre)
#
# Association Rules:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric]
# Index: []
# C:\Users\hDibie\AppData\Local\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
import nltk

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\hDibie\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

# Initialize the sentiment analyzer
sia = SentimentIntensityAnalyzer()

# Example customer reviews
customer_reviews = [
    "The product was excellent! I'm really satisfied with my purchase.",
    "The customer service was terrible. They were unhelpful and rude.",
    "I had a mixed experience with the product. It has some good features, but also some drawbacks.",
    "I love this company! They always deliver top-notch products and provide great support."
]

# Perform sentiment analysis on each customer review
sentiments = []
for review in customer_reviews:
    sentiment = sia.polarity_scores(review)
    sentiments.append(sentiment)

# Print the sentiment scores for each review
for i, sentiment in enumerate(sentiments):
    print(f"Review {i+1}: {customer_reviews[i]}")
    print(f"Sentiment: {sentiment}")
    print()
# Out:
# Review 1: The product was excellent! I'm really satisfied with my purchase.
# Sentiment: {'neg': 0.0, 'neu': 0.53, 'pos': 0.47, 'compound': 0.7955}
#
# Review 2: The customer service was terrible. They were unhelpful and rude.
# Sentiment: {'neg': 0.433, 'neu': 0.567, 'pos': 0.0, 'compound': -0.7269}
#
# Review 3: I had a mixed experience with the product. It has some good features, but also some drawbacks.
# Sentiment: {'neg': 0.0, 'neu': 0.878, 'pos': 0.122, 'compound': 0.2382}
#
# Review 4: I love this company! They always deliver top-notch products and provide great support.
# Sentiment: {'neg': 0.0, 'neu': 0.444, 'pos': 0.556, 'compound': 0.906}

# %%
# Calculate average order value
average_order_value = merged_data['unitPrice_x'].mean()

# Estimate purchase frequency
total_orders = merged_data['orderID'].nunique()
total_customers = merged_data['customerID'].nunique()
purchase_frequency = total_orders / total_customers

# Define the average customer lifespan (in months)
average_customer_lifespan = 12

# Calculate the CLV
clv = average_order_value * purchase_frequency * average_customer_lifespan

# Print the CLV
print("Estimated CLV: $", clv)
# Out:
# Estimated CLV: $ 3127.7406772856434
